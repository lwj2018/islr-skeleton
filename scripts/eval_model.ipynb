# %%
import torch
model_path = "/home/liweijie/experiment_result/models/20191203iSLR_simple_fusion_class500_best.pth.tar"
checkpoint = torch.load(model_path)

print("epoch: %d, best_prec1: %.3f, best_prec5: %.3f"%(checkpoint["epoch"],checkpoint["best_prec1"],checkpoint["best_prec5"]))
# Out:
# epoch: 156, best_prec1: 79.200, best_prec5: 95.929

# %%
import torch
model_path = "/home/liweijie/experiment_result/models/iSLR_RGB_resnet18_class500_hidden1024_best.pth.tar"
checkpoint = torch.load(model_path)

print("epoch: %d, best_prec1: %.3f"%(checkpoint["epoch"],checkpoint["best_prec1"]))
checkpoint
# Out:
# epoch: 36, best_prec1: 63.643
# {'epoch': 36,
#  'arch': 'resnet18',
#  'state_dict': OrderedDict([('module.base_model.conv1.weight',
#                tensor([[[[-1.5264e-02, -1.4516e-02, -1.1052e-02,  ...,  4.8422e-02,
#                            1.1481e-02, -1.6382e-02],
#                          [ 4.4406e-03,  4.9648e-04, -1.1442e-01,  ..., -2.6906e-01,
#                           -1.3042e-01, -9.4735e-04],
#                          [-1.4595e-02,  4.7638e-02,  2.7581e-01,  ...,  4.9195e-01,
#                            2.4103e-01,  5.7965e-02],
#                          ...,
#                          [-3.5640e-02,  4.9815e-03,  6.2756e-02,  ..., -3.2297e-01,
#                           -4.0453e-01, -2.4913e-01],
#                          [ 2.2001e-02,  3.1135e-02,  5.4763e-02,  ...,  3.9507e-01,
#                            3.7766e-01,  1.5952e-01],
#                          [-1.8704e-02, -9.4215e-03, -2.6348e-02,  ..., -1.4775e-01,
# ...

# %%
a = np.ones([2,2])
b = np.ones([6,2])
c = np.matmul(a,b.transpose())
c
# Out:
# array([[2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2.]])

# %%
import torch
a = torch.zeros(2,2,1)
